# %%
operaciones = input(" Ingresa una operación: suma, resta, division, multiplicacion, potencia ")
num_1 = input(" Ingrese el primer numero ")
num_2 = input(" Ingrese el sugundo numero ")

num1 = int(num_1)
num2 = int(num_2)

resultado = 0

if operaciones == 'suma':
    resultado = num1 + num2
    operacion = "+"
elif operaciones == 'resta':
    resultado = num1 - num2
    operacion = "-"
elif operaciones == 'multiplicacion':
    reultado = num1 * num2
    operacion = "*"
elif operaciones == 'division':
    resultado = num1 / num2
    operacion = "/"
elif operaciones == 'potencia':
    resultado = num1 ** num2
    operacion = "**"

print(f"El resultado es: {num1} {operacion} {num2} = {resultado}")
# Out:
#  Ingresa una operación: suma, resta, division, multiplicacion, potencia  suma
#  Ingrese el primer numero  4
#  Ingrese el sugundo numero  5
# El resultado es: 4 + 5 = 9
